# %%
import streamlit as st
import requests
import uuid
import os
from datetime import datetime

# Constants
WEBHOOK_URL = "https://akshatshaw.app.n8n.cloud/webhook-test/c5ce3d8c-8ffb-459b-8105-3946467ce1cd"

BEARER_TOKEN = "admin123"

def generate_session_id():
    return str(uuid.uuid4())

def send_message_to_llm(session_id, message):
    headers = {
        "Authorization": f"Bearer {BEARER_TOKEN}",
        "Content-Type": "application/json"   
    }
    payload = {
        "sessionId": session_id,
        "chatInput": message
    }
    response = requests.post(WEBHOOK_URL, json=payload, headers=headers)
    
    if response.status_code == 200:
        content_type = response.headers.get('Content-Type', '')
        
        if 'audio' in content_type or 'mp3' in content_type or 'wav' in content_type:
            return {"type": "audio", "content": response.content}
        else:
            try:
                return {"type": "text", "content": response.json()["output"]}
            except:
                return {"type": "audio", "content": response.content}
    else:
        return {"type": "text", "content": f"Error: {response.status_code} - {response.text}"}

# %%
response = send_message_to_llm(generate_session_id(), "hi there")
with open(audio_path, "wb") as f:
            f.write(llm_response["content"])
# Out:
# {'type': 'audio',
#  'content': b'ID3\x04\x00\x00\x00\x00\x00#TSSE\x00\x00\x00\x0f\x00\x00\x03Lavf59.27.100\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\xfb\x90\xc4\x00\x00\x0e\xf9\xa3\x05#\x0cxb\xe8:\x1f\x85\x86$)\x00\xadX\x08\x96\xc7\x90U\xd92v\x9a\x04\x10A\xee\xee\xd0\x88\x88\x88\x84.\xff\xfd\xee\xc8\x10 @\x84DC\xbb\xbb\xbb\xbb\xa0\x84DB\xfe\x7f\xf4\xd1\x0bwp\xe2\xc4\'\x87\x03s\x8f\x87\x03wwq\x08\x10\x01\x00\x04\x00\x00\x0bws\xfe\xa7\x11?\xd1(\x18\x18\x1b\x9cw\xf4([\xbb\x9d\x17(\xb0\x00\x02\xd3}\x1c\xd0\x01\x02\x00\x16xww\xa7\xa7\x04X_\x11\x02\x00\x08E| \x84D@\x82\x1c\x0c\xc0\'3~\x12\x9a\xb0\xa4\xadbS\'\'\xa2I4\xc4\x94\xc9+\x12\x0f@T\xd6\x9aO\x16\xf1eT$\xaa\xac\x8d\xfa\xbc\xdd\x8a\xb8\xd6E\x06\xc9\xa2$a\x97\x1d2T\x856VE\xd2\x9a\xca {\x95e\x0b(q\x94\xa2\xac\xd4fg\xe4\xd6D\x85F~1\x9drd\xe4\xbe\xec\r\xcbwR\x86#\x83\x12\xb5\xe1\x1b\x9fMY\xc1$\n%\x8b\x86\xdbh\xc3\xe2\x8cI5\xda.qC\x12n*\xd2\xf1#i6\x03\xc2\x8a\xc6\x902\xa3\xcb\x91\x9fM\xa4\x02\x82\xf0e\xa4\xd0\x1c\x03\x069\xb20L\xf9\x1c\x1cVh\x1b#z4\x89:xA\x